# %% [markdown]
# Technological Institute of the Philippines | Quezon City - Computer Engineering
# --- | ---
# Course Code: | CPE 018
# Code Title: | Emerging Technologies in CpE 1 - Fundamentals of Computer Vision
# 1st Semester | AY 2023-2024
# <hr> | <hr>
# <u>**ACTIVITY ** | **ORB Feature Detection and Feature Matching**
# **Name** | Figueras, Jose Enrico
# **Section** | CPE31S3
# **Date Performed**: | 10/28/23
# **Date Submitted**: | 10/28/23
# **Instructor**: | Engr. Roman M. Richard
#
# <hr>

# %% [markdown]
# ## 1. Objectives

# %% [markdown]
# This activity aims to enable students to perform feature detection and feature matching using Oriented FAST and Rotated BRIEF (ORB) algorithm with OpenCV.

# %% [markdown]
# ## 2. Intended Learning Outcomes (ILOs)
# After this activity, the students should be able to:
# * Demonstrate the use of oriented FAST and rotated BRIEF algorithm implemented through the use of OpenCV, debugging and modification.
# * Evaluate feature detection using Oriented FAST and rotated BRIEF algorithm on images to detect important features.

# %% [markdown]
# ## 3. Procedures and Outputs

# %% [markdown]
# **BEFORE YOU PROCEED WITH THIS SECTION: PLEASE MAKE SURE YOU HAVE READ THE CONTENTS OF THE MODULE REGARDING BRIEF AND FAST**

# %% [markdown]
# The team that created ORB (Ethan Rublee, Vincent Rabaud, Kurt Konolige, and Gary R. Bradski) chose to build it on FAST and BRIEF because these two algorithms are fast and efficient.
#
# In their paper, the authors of ORB set out to achieve the following:
#
# * Add a fast and accurate way to determine the orientation of FAST keypoints.
# * Find a way to efficiently compute BRIEF features that are also rotation-invariant.
# Analyze the variance and correlation of oriented BRIEF features.
# * Develop a learning method to decorrelate BRIEF features under rotational invariance, which would improve performance in nearest-neighbor applications.
# * In other words, the ORB team wanted to make feature detection and matching faster and more accurate, especially in situations where the training image and query image have different rotations.
#
# The main points of the text are clear, even if you don't understand all of the technical jargon. ORB is a fast and efficient algorithm for feature detection and matching, and it is especially good at matching features that have different rotations.
#
# I bet you are eager to start coding with ORB, so let's move on to some code examples.

# %% [markdown]
# Parts of this activity contribute towards the attainment of `ILO1: Demonstrate the use of oriented FAST and rotated BRIEF algorithm implemented through the use of OpenCV, debugging and modification.`

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

image1 = cv2.imread('/content/playstation-47410.jpg', cv2.IMREAD_GRAYSCALE)
image2 = cv2.imread('/content/s-l1600.jpg', cv2.IMREAD_GRAYSCALE)

# %%
# Preview the 2 images
cv2_imshow(image1)
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=L size=866x650>
# <PIL.Image.Image image mode=L size=1198x898>

# %%
# Create the ORB feature and detector descriptor
orb = cv2.ORB_create()

kp1, des1 = orb.detectAndCompute(image1,None) # Reference image
kp2, des2 = orb.detectAndCompute(image2,None)

# %% [markdown]
# **Analysis: Explain the purpose of detector and descriptor and why they're used here.**

# %% [markdown]
# The purpose of these detector and descriptor is to detect the features in the image and then adds a descriptor to each feature as well as the coordinates of these features.

# %%
"""
The BFMatcher is a simple but effective algorithm for feature matching.
It works by comparing each feature in one image to every feature in the other
image and returning the pair of features with the smallest distance.
"""

bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

"""
The match() method takes two arguments:
  - the descriptors of the features in the first image
  - the descriptors of the features in the second image.

It returns a list of matches, where each match is a pair of feature indices,
one from each image.
"""

matches = bf.match(des1,des2)

# %%
"""
Next, we sort the matches in order of their distance.
This ensures that the best matches are returned first.
"""
sorted_matches = sorted(matches, key = lambda x:x.distance)

"""
Then, we draw the top 40 matches between the two images.
The drawMatches() method takes two arguments: the two images, and a list of matches.
It draws lines between the corresponding keypoints in the two images.
"""

image3 = cv2.drawMatches(image1,kp1,image2,kp2, sorted_matches[:40],image2,flags=2)

# %%
from matplotlib import pyplot as plt

plt.imshow(image3)
plt.show()

# %% [markdown]
# **Question**
# - Provide an analysis on the way the ORB algorithm works here, are the results correct? What can/should be improved?

# %% [markdown]
# ## 4. Supplementary Activity

# %% [markdown]
# **ILO2: Evaluate feature detection using Oriented FAST and rotated BRIEF algorithm on images to detect important features.**
#
# Perform the following tasks:
# 1. Find 2 images of brand logos on the internet.
# 2. Find 5 product images containing one logo each.
# 3. Test the ORB algorithm to detect and match the features on the images. Document the testing.
# 4. Evaluate the algorithm's performance, was it able to detect the important features? Was it also reliable in not finding the logos that are not on the provided images?
# 5. Provide an analysis: Why did it work, or otherwise? What would you change to improve the results if you could?

# %%
# 1. Find 2 images of brand logos on the internet.

jbee = cv2.imread('/content/jbee.jpg', cv2.IMREAD_GRAYSCALE)
sb = cv2.imread('/content/sb.jpg', cv2.IMREAD_GRAYSCALE)
cv2_imshow(jbee)
cv2_imshow(sb)
# Out:
# <PIL.Image.Image image mode=L size=1280x1280>
# <PIL.Image.Image image mode=L size=1200x1215>

# %%
# 2. Find 5 product images containing one logo each.

j1 = cv2.imread('/content/j1.jpg', cv2.IMREAD_GRAYSCALE)
j2 = cv2.imread('/content/j2.jpg', cv2.IMREAD_GRAYSCALE)
j3 = cv2.imread('/content/j3.jpg', cv2.IMREAD_GRAYSCALE)
j4 = cv2.imread('/content/j4.jpg', cv2.IMREAD_GRAYSCALE)
j5 = cv2.imread('/content/j5.jpg', cv2.IMREAD_GRAYSCALE)

s1 = cv2.imread('/content/s1.jpg', cv2.IMREAD_GRAYSCALE)
s2 = cv2.imread('/content/s2.jpg', cv2.IMREAD_GRAYSCALE)
s3 = cv2.imread('/content/s3.jpg', cv2.IMREAD_GRAYSCALE)
s4 = cv2.imread('/content/s4.jpg', cv2.IMREAD_GRAYSCALE)
s5 = cv2.imread('/content/s5.jpg', cv2.IMREAD_GRAYSCALE)

# %%
# 3. Test the ORB algorithm to detect and match the features on the images. Document the testing.
orb = cv2.ORB_create()

kp1, des1 = orb.detectAndCompute(jbee, None)
kp2, des2 = orb.detectAndCompute(sb, None)

kp3, des3 = orb.detectAndCompute(j1, None)
kp4, des4 = orb.detectAndCompute(j2, None)
kp5, des5 = orb.detectAndCompute(j3, None)
kp6, des6 = orb.detectAndCompute(j4, None)
kp7, des7 = orb.detectAndCompute(j5, None)

kp8, des8 = orb.detectAndCompute(s1, None)
kp9, des9 = orb.detectAndCompute(s2, None)
kp10, des10 = orb.detectAndCompute(s3, None)
kp11, des11 = orb.detectAndCompute(s4, None)
kp12, des12 = orb.detectAndCompute(s5, None)


bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

# %%
matchJBee = bf.match(des1,des3)
matchJBee1 = bf.match(des1,des5)
matchSB = bf.match(des2,des10)
matchSB1 = bf.match(des2,des11)

# %%
sorted_matchJBee = sorted(matchJBee, key = lambda x:x.distance)
sorted_matchJBee1 = sorted(matchJBee1, key = lambda x:x.distance)
imageJBee = cv2.drawMatches(jbee,kp1,j1,kp3, sorted_matches[:40],j1,flags=2)
imageJBee1 = cv2.drawMatches(jbee,kp1,j3,kp5, sorted_matches[:40],j3,flags=2)

# %%
plt.imshow(imageJBee)
plt.show()

# %%
plt.imshow(imageJBee1)
plt.show()

# %%
sorted_matchSB = sorted(matchSB, key = lambda x:x.distance)
sorted_matchSB1 = sorted(matchSB1, key = lambda x:x.distance)

imageSB = cv2.drawMatches(sb,kp2,s1,kp8, sorted_matches[:40],s1,flags=2)
imageSB1 = cv2.drawMatches(sb,kp2,s4,kp11, sorted_matches[:40],s4,flags=2)

# %%
plt.imshow(imageSB)
plt.show()

# %%
plt.imshow(imageSB1)
plt.show()

# %% [markdown]
# 4. Evaluate the algorithm's performance, was it able to detect the important features? Was it also reliable in not finding the logos that are not on the provided images?
#
# I think that the algorithm's performance still has inaccuracies and it is up to the user how these inaccuracies can be improved. Though it is still effective in detecting the important features, it has a flaw that makes it think that a feature of the other image exhibits a property of the logo even if it does not. With these observations, I think that the answer two the second question would be no, it is not reliable in finding the logos that are not on the provided images, as it detects objects/features that are part of the image, where the logo is not present.

# %% [markdown]
# 5. Provide an analysis: Why did it work, or otherwise? What would you change to improve the results if you could?
#
# Though it did work, one observation that I have noticed is that there is a tendency the algorithm still detects logos where there is none present is because of the lighting of the image, the shadows causes the algorithm that the object found in the logo is also found in darkened areas. A suggestion to the users would be to use clear images with little to no shadowing. Or if the algorithm can still be improved, then I suggest to work on this part of the algorithm.

# %% [markdown]
# ## 5. Summary, Conclusions and Lessons Learned

# %% [markdown]
# This activity introduced to us the ORB Feature Detection and Feature Matching, being applied to logo detection betweek two images with both images having the same logo present. The activity made us analyze how the algorithm works and gave us a supplementary activity wherein we get to implement it into logos of our own choosing. This ORB Feature Detection algorithm is helpful for future use as we continue to apply Computer Vision to images, videos, etc. in this course subject.

# %% [markdown]
# <hr/>
#
# ***Proprietary Clause***
#
# *Property of the Technological Institute of the Philippines (T.I.P.). No part of the materials made and uploaded in this learning management system by T.I.P. may be copied, photographed, printed, reproduced, shared, transmitted, translated, or reduced to any electronic medium or machine-readable form, in whole or in part, without the prior consent of T.I.P.*
